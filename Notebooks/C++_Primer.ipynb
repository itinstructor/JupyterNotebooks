# %% [markdown]
# <a href="https://colab.research.google.com/github/itinstructor/JupyterNotebooks/blob/main/Notebooks/C%2B%2B_Primer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # C++ Basics
#
# C++ (pronounced see plus plus) is a general purpose programming language that is free-form and compiled. It is regarded as an intermediate-level language, as it comprises both high-level and low-level language features. It provides imperative, object-oriented and generic programming features.
#
# C++ is one of the most popular programming languages and is implemented on a wide variety of hardware and operating system platforms. As an efficient performance driven programming language it is used in systems software, application software, device drivers, embedded software, high-performance server and client applications, and entertainment software such as video games. Various entities provide both open source and proprietary C++ compiler software, including the FSF, LLVM, Microsoft and Intel
#
# **What is C++**
# C++ is a cross-platform language that can be used to create high-performance applications.
#
# **Who developed C++**
# C++ was developed by Bjarne Stroustrup.

# %% [markdown]
# ### Colab and Linux
#
# Google Colab runs in a Linux Cloud VM (Virtual Machine). You can access most of the bash command with a `!` added in the front of the command.
#
# Use the following code to find out the Colab Linux version.

# %%
# !cat /etc/*release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"
# NAME="Ubuntu"
# VERSION="18.04.5 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.5 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %% [markdown]
# One feature of Google Colab is the ability to use cloud GPU for heavy processing. Only turn this on if needed.
#
# You can turn on the GPU from `Runtime`->`Change Runtime Type`->`Hardware Acceleration`

# %% [markdown]
# # Compile C++

# %% [markdown]
# Colab is built on a Linux platform. We can use G++ to compile and run C++ programs with a few magic commands.
#
# Any files written to the Colab workspace disapear when you leave your Colab session. Run the cell again to re write the file.
#
# **%%writefile** will write your program file to temporary file storage.

# %%
# %%writefile hello_world.cpp
# #include <iostream>
# int	main()
# {
# 	std::cout << "Hello C++ in Colab World! ;')\n";
# 	return 0;
# }
# Out:
# Writing hello_world.cpp

# %% [markdown]
# The Linux **ls -l** command will list the files in the current working directory.

# %%
# !ls -l
# Out:
# total 36
# -rwxr-xr-x 1 root root 8776 Apr 26 13:04 hello_world
# -rw-r--r-- 1 root root   94 Apr 26 13:02 hello_world.cpp
# drwxr-xr-x 1 root root 4096 Apr 19 14:23 sample_data
# -rwxr-xr-x 1 root root 8776 Apr 26 13:02 test
# -rw-r--r-- 1 root root   94 Apr 26 13:00 test.cpp

# %% [markdown]
# **%%shell** gives us access to the Linux shell for the duration of the code cell run.
#
# Use g++ to compile the program.

# %%
# %%shell
# # Compile with g++
# g++ hello_world.cpp -o hello_world
# # Run the program
# ./hello_world
# Out:
# Hello C++ in Colab World! ;')

# %% [markdown]
# That is how C++ works in Colab. We use the underlying Linux OS to compile and run C++.
