# %% [markdown]
# <a href="https://colab.research.google.com/github/itinstructor/JupyterNotebooks/blob/main/Python_Data_Science_Primer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bill's Python Data Science Primer, Life, the Universe, and Everything

# %% [markdown]
# This tutorial uses Python in a Google Colab notebook. We will also work with, three fundamental tools for data science and machine learning in Python.
# * NumPy
# * Pandas
# * Matplotlib

# %% [markdown]
# # Jupyter Notebooks

# %% [markdown]
# We will use Jupyter notebooks to practice data science and machine learning. Notebooks are a great way to mix executable code with rich contents (HTML, images, equations written in LaTeX). Google Colab allows us to run notebooks on the cloud for free without a local installation.

# %% [markdown]
# You are working in an interactive environment called a notebook. A notebook allows you write and execute code and text. Notebooks consist of code cells or text cells.
#
# - This is a text cell.
# - Below is a code cell that stores the result of a computation (the number of seconds in a day) in a variable and print its value:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Click on the "play" button to execute the cell. You should be able to see the result. You can also execute the cell by pressing Ctrl + Enter if you are on Windows / Linux or Command + Enter if you are on a Mac.

# %% [markdown]
# Variables that you defined in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# The order of execution is important. For instance, if we do not run the cell storing *seconds_in_a_day* beforehand, the above cell will raise an error, as it depends on this variable. To ensure that you run all the cells in the correct order, you can click on "Runtime" in the top-level menu, then "Run all".

# %% [markdown]
# ## Going Further

# %% [markdown]
# * Google Colab [Basic Features Overview](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
# * Markdown Guide for Google Colab (How to format a notebook) [Notebook Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)

# %% [markdown]
# ## Exercise

# %% [markdown]
# **Exercise 1.** Add a cell below this cell: click on this cell then click on "+ Code". In the new cell, compute the number of seconds in a year by reusing the variable *seconds_in_a_day*. Run the new cell.

# %% [markdown]
# # Python

# %% [markdown]
# Almost all Python code will run in Colab. Let's take a look at some common Python concepts in a notebook environment.

# %%
# Find the Python version in a notebook
import sys
print(f"Python: {sys.version}")
# Out:
# Python: 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]

# %% [markdown]
# ## Arithmetic Operations

# %% [markdown]
# Python supports the usual arithmetic operators:
# * \+ (addition)
# * \* (multiplication)
# * / (division)
# * \** (power)
# * // (integer division).

# %%
a = 5
b = 89
c = a + b
# You can using the Python print command
print(f"a + b = {c}")
# To print a variable or expression, you can also put it on the last line
c
# Out:
# a + b = 94
# 94

# %% [markdown]
# ## Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized as an empty list.

# %%
my_list = []

# %% [markdown]
# A list can be initialized with some initial elements.

# %%
my_list = [1, 2, 3]
my_list
# Out:
# [1, 2, 3]

# %% [markdown]
# Lists are mutable. They have a dynamic size and elements can be added (appended) to them.

# %%
my_list.append(4)
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# We can access individual elements of a list (indexing starts from 0)

# %%
my_list[2]
# Out:
# 3

# %% [markdown]
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:

# %%
my_list[1:3]
# Out:
# [2, 3]

# %% [markdown]
# Omitting the second index means that the slice should run until the end of the list

# %%
my_list[1:]
# Out:
# [2, 3, 4]

# %% [markdown]
# We can check if an element is in the list using `in`

# %%
my_list = [1, 3, 5, 7, 9]
if 5 in my_list:
    print("5 is in the list")
else:
    print("5 is not in mylist")
# Out:
# 5 is in the list

# %% [markdown]
# The length of a list can be obtained using the `len` function

# %%
len(my_list)
# Out:
# 5

# %% [markdown]
# The shuffle() method takes a sequence, like a list, and reorganizes the order of the items.

# %%
import random

mylist = ["apple", "banana", "cherry"]
random.shuffle(mylist)

print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# ## Strings

# %% [markdown]
# The string data type stores text. In Python, they can delimited using either single quotes or double quotes.

# %%
string1 = "some text"
string2 = 'some other text'

# %% [markdown]
# Strings behave similarly to lists. We can access individual elements in exactly the same way.

# %%
string1[3]
# Out:
# 'e'

# %% [markdown]
# and similarly for slices

# %%
string1[5:]
# Out:
# 'text'

# %% [markdown]
# String concatenation is performed using the `+` operator

# %%
string1 + " " + string2
# Out:
# 'some text some other text'

# %% [markdown]
# ## Conditionals

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.

# %%
my_variable = 5
if my_variable < 0:
    print("negative")
elif my_variable == 0:
    print("null")
else: # my_variable > 0
    print("positive")
# Out:
# positive

# %% [markdown]
# Here `<` and `>` are the strict `less` and `greater than` operators, while `==` is the equality operator (not to be confused with `=`, the variable assignment operator). The operators `<=` and `>=` can be used for less (resp. greater) than or equal comparisons.

# %% [markdown]
# Contrary to other languages, blocks of code are delimited using indentation. It is common practice to use 4-space indentation.

# %% [markdown]
# ## Loops

# %% [markdown]
# Loops are a way to execute a block of code multiple times. There are two main types of loops: while loops and for loops.

# %% [markdown]
# While loop

# %%
i = 0
while i < len(my_list):
    print(my_list[i])
    i += 1 # equivalent to i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# For loop using the range function.

# %%
for i in range(len(my_list)):
    print(my_list[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Iterate over a list.

# %%
for element in my_list:
    print(element)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Functions

# %% [markdown]
# To improve code readability, it is common to separate the code into different blocks, responsible for performing precise actions: functions. A function takes some inputs and process them to return some outputs.

# %%
def square(x):
    return x ** 2

def multiply(a, b):
    return a * b

# Functions can be composed.
square(multiply(3, 2))
# Out:
# 36

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Write a program that finds the largest of 2 values.

# %%
def maximum(x, y):
  # Write your function here
  return

maximum(5,17)

# %% [markdown]
# **Exercise 2.** Write a function that sorts a list in ascending order (from smaller to bigger) using the [bubble sort](https://en.wikipedia.org/wiki/Bubble_sort) algorithm.

# %%
def bubble_sort(my_list):
  # Write your function here
  return

my_list = [1, -3, 3, 2]
# Should return [-3, 1, 2, 3]
bubble_sort(my_list)

# %% [markdown]
# ## Going Further

# %% [markdown]
# It is impossible to cover all the language features in this short introduction. To go further, we recommend the following resources:

# %% [markdown]
# * [Python Tutorial with Google Collab](https://colab.research.google.com/github/cs231n/cs231n.github.io/blob/master/python-colab.ipynb)
# *   List of Python [tutorials](https://wiki.python.org/moin/BeginnersGuide/Programmers)
# * Four-hour [course](https://www.youtube.com/watch?v=rfscVS0vtbw) on Youtube

# %% [markdown]
# # NumPy

# %% [markdown]
# NumPy is a popular library for storing arrays of numbers and performing computations on them. This enables us to write often more succint code, this also makes the code faster, since most NumPy routines are implemented in C for speed.

# %%
# Find the numpy version in a notebook
import sys
import numpy
print(f"numpy: {numpy.__version__}")
# Out:
# numpy: 1.21.6

# %% [markdown]
# To use NumPy in your program, import it as follows

# %%
# Import numpy library
import numpy as np

# %% [markdown]
# ## Array Creation

# %% [markdown]
# NumPy arrays can be created from Python lists. This is a single dimension NumPy array.

# %%
# Import numpy library
import numpy as np
my_array = np.array([1, 2, 3])
my_array
# Out:
# array([1, 2, 3])

# %% [markdown]
# Access a NumPy array element

# %%
# Access an element
my_array[2]
# Out:
# 3

# %% [markdown]
# NumPy supports arrays of arbitrary dimensions. For example, we can create two-dimensional arrays (e.g. to store a matrix) as follows

# %%
my_2d_array = np.array([[1, 2, 3], [4, 5, 6]])
my_2d_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# Access individual elements of a 2d-array using two indices

# %%
my_2d_array[1, 2]
# Out:
# 6

# %% [markdown]
# We can access rows

# %%
my_2d_array[1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# and columns

# %%
my_2d_array[:, 2]
# Out:
# array([3, 6])

# %% [markdown]
# Arrays have a `shape` attribute

# %%
print(my_array.shape)
print(my_2d_array.shape)
# Out:
# (3,)
# (2, 3)

# %% [markdown]
# Contrary to Python lists, NumPy arrays must have a type and all elements of the array must have the same type.

# %%
my_array.dtype
# Out:
# dtype('int64')

# %% [markdown]
# The main types are `int32` (32-bit integers), `int64` (64-bit integers), `float32` (32-bit real values) and `float64` (64-bit real values).

# %% [markdown]
# The `dtype` can be specified when creating the array

# %%
my_array = np.array([1, 2, 3], dtype=np.float64)
my_array.dtype
# Out:
# dtype('float64')

# %% [markdown]
# We can create arrays of all zeros using

# %%
zero_array = np.zeros((2, 3))
zero_array
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# and similarly for all ones using `ones` instead of `zeros`.

# %% [markdown]
# We can create a range of values using

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# or specifying the starting point

# %%
np.arange(3, 5)
# Out:
# array([3, 4])

# %% [markdown]
# Another useful routine is `linspace` for creating linearly spaced values in an interval. For instance, to create 10 values in `[0, 10]`, we can use

# %%
np.linspace(0, 10, 5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %% [markdown]
# Another important operation is `reshape`, for changing the shape of an array

# %%
my_array = np.array([1, 2, 3, 4, 5, 6])
my_array.reshape(3, 2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# Play with these operations and make sure you understand them well.

# %% [markdown]
# ## Basic Operations

# %% [markdown]
# In NumPy, we express computations directly over arrays. This makes the code much more succint.

# %% [markdown]
# Arithmetic operations can be performed directly over arrays. For instance, assuming two arrays have a compatible shape, we can add them as follows

# %%
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])
array_a + array_b
# Out:
# array([5, 7, 9])

# %% [markdown]
# Compare this with the equivalent computation using a for loop without direct array math.

# %%
array_out = np.zeros_like(array_a)
for i in range(len(array_a)):
  array_out[i] = array_a[i] + array_b[i]
array_out
# Out:
# array([5, 7, 9])

# %% [markdown]
# Not only this code is more verbose, it will also run much more slowly.

# %% [markdown]
# In NumPy, functions that operates on arrays in an element-wise fashion are called [universal functions](https://numpy.org/doc/stable/reference/ufuncs.html). For instance, this is the case of `np.sin`

# %%
np.sin(array_a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %% [markdown]
# Vector inner product can be performed using `np.dot`

# %%
np.dot(array_a, array_b)
# Out:
# 32

# %% [markdown]
# When the two arguments to `np.dot` are both 2d arrays, `np.dot` becomes matrix multiplication

# %%
array_A = np.random.rand(5, 3)
array_B = np.random.randn(3, 4)
np.dot(array_A, array_B)
# Out:
# array([[ 0.1553269 ,  1.95679533,  0.38993262, -0.51527804],
#        [ 2.16197532,  0.78755168, -0.9280513 ,  0.03025355],
#        [ 0.47432701,  1.91750717,  0.37799975, -0.37450576],
#        [ 0.38516932,  1.0454573 ,  0.20813944, -0.15082499],
#        [ 0.83313878,  2.29368286,  0.63992983, -0.2297391 ]])

# %% [markdown]
# Matrix transpose can be done using `.transpose()` or `.T` for short

# %%
array_A.T
# Out:
# array([[0.57648182, 0.23621315, 0.36994424, 0.12069089, 0.05137131],
#        [0.04633825, 0.83548651, 0.23368913, 0.20280476, 0.50899183],
#        [0.94604048, 0.22168032, 0.84510967, 0.427279  , 0.87556987]])

# %% [markdown]
# ## Slicing and Masking

# %% [markdown]
# Like Python lists, NumPy arrays support slicing

# %%
np.arange(10)[5:]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# We can also select only certain elements from the array

# %%
x = np.arange(10)
mask = x >= 5
x[mask]
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# ##Statistics

# %% [markdown]
# Numpy is full of statistical operations. These operations are performed directly on an array. This makes these operations very fast even on very big datasets.

# %%
import numpy as np
my_array = np.array([1, 2, 3, 4, 5, 6])
print(my_array)
print(f"Average: {np.average(my_array)}")
print(f"Mean: {np.mean(my_array)}")
print(f"Median: {np.median(my_array)}")
print(f"Standard Deviation: {np.round(np.std(my_array),2)}")
print(f"Variance: {np.round(np.var(my_array),2)}")
print(f"Max: {np.max(my_array)}")
print(f"Min: {np.min(my_array)}")
print(f"Range of Values: {np.ptp(my_array)}")
print(f"Sum: {np.sum(my_array)}")
print(f"Product: {np.product(my_array)}")
print(f"Square: {np.square(my_array)}")
# Out:
# [1 2 3 4 5 6]
# Average: 3.5
# Mean: 3.5
# Median: 3.5
# Standard Deviation: 1.71
# Variance: 2.92
# Max: 6
# Min: 1
# Range of Values: 5
# Sum: 21
# Product: 720
# Square: [ 1  4  9 16 25 36]

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.** Create a 2d NumPy array of shape (2, 2), containing 4 values. Access individual elements and slices.

# %%
import numpy as np
# Write your code here

# %% [markdown]
# **Exercise 2.** Create a 1 D NumPy array of 10 integers. Compute the mean, median and average of the array.

# %%
import numpy as np
# Write your code here

# %% [markdown]
# ## Going Further

# %% [markdown]
# * Python Data Science Handbook [Chapter 2: Introduction to Numpy](https://jakevdp.github.io/PythonDataScienceHandbook/02.00-introduction-to-numpy.html)
# * One-hour Numpy [tutorial](https://www.youtube.com/watch?v=QUT1VHiLmmI) on Youtube

# %% [markdown]
# # Pandas

# %% [markdown]
# pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.

# %%
# Find the pandas version in a notebook
import sys
import pandas
print(f"pandas: {pandas.__version__}")
# Out:
# pandas: 1.3.5

# %%
# Import pandas library
import pandas as pd

# %% [markdown]
# ## DataFrame Creation

# %% [markdown]
# Let's create a pandas data from a Python dictionary.
# Fred has a fruit stand that sells organic apples and oranges. We want to have a column for each fruit and a row for each customer purchase.
#
# Each (key, value) item in data corresponds to a column in the resulting DataFrame.

# %%
import pandas as pd
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}
# Pass dictionary to pandas DataFrame constructor
purchases = pd.DataFrame(data)
# Display dataframe
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# The Python programming language has a variety of built-in data structures such as lists, tuples, dictionaries, strings, and sets. These data structures are ideal for storing data during program execution, however, they can not be efficiently used to perform analytical tasks such as exploratory analysis and data visualization. Pandas library can transfer Python data structures into DataFrame objects to allow users to easily perform data manipulation and analytics.
#
# For example, imagine we have a Python dictionary to save country information such as below:

# %%
import pandas as pd
# Create a Python dictionary
{'country_name':'New Zealand',
 'capital_city':'Wellington',
 'country_code':'NZ',
 'population':4783063,
 'area_km2':270467}
# Out:
# {'area_km2': 270467,
#  'capital_city': 'Wellington',
#  'country_code': 'NZ',
#  'country_name': 'New Zealand',
#  'population': 4783063}

# %% [markdown]
# The dictionary key represents the attribute label or title while the dictionary value represents the corresponding information. Pandas library can convert a list of similar dictionaries into a DataFrame object as shown in the example below:

# %%
# Create a list of dictionaries
list_of_countries = [
 {'country_name':'China','capital_city':'Beijing','population':1433783686,'area_km2':9596961},
{'country_name':'New Zealand','capital_city':'Wellington','population':4783063,'area_km2':270467},
{'country_name':'South Africa','capital_city':'Pretoria','population':58558270,'area_km2':1221037},
{'country_name':'United Kingdom','capital_city':'London','population':67530172,'area_km2':242495},
{'country_name':'United States','capital_city':'Washington DC','population':329064917,'area_km2':9525067}   
]
# Create a Pandas DataFrame from a list of dictionaries
countries = pd.DataFrame(list_of_countries, index = ['CN','NZ','ZA','GB','US'])
# Display the DataFrame using the head() method
print(countries.head())
print()
# Display the DataFrame using the tail() method
print(countries.tail())
# Out:
#       country_name   capital_city  population  area_km2
# CN           China        Beijing  1433783686   9596961
# NZ     New Zealand     Wellington     4783063    270467
# ZA    South Africa       Pretoria    58558270   1221037
# GB  United Kingdom         London    67530172    242495
# US   United States  Washington DC   329064917   9525067
#
#       country_name   capital_city  population  area_km2
# CN           China        Beijing  1433783686   9596961
# NZ     New Zealand     Wellington     4783063    270467
# ZA    South Africa       Pretoria    58558270   1221037
# GB  United Kingdom         London    67530172    242495
# US   United States  Washington DC   329064917   9525067

# %% [markdown]
# ## Colab Access to Google Drive

# %% [markdown]
# We will be working with csv, .xls, and other common dataset files. There are many free dataset files for download. You can access files directly from your Google drive.
# 1.   Insert the following code into a data cell at the top of your notebook.
# 2.   Run the code.
# 3.   Follow the directions in the Assignment to download the IMDB-Movie-Data.csv file.

# %%
# Mount your Google drive in colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##CSV Datasets

# %%
import pandas as pd
df = pd.read_csv (r'/content/drive/MyDrive/Colab Notebooks/Datasets/IMDB-Movie-Data.csv')
print(df.head(5))
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# We will use one of the CSV Datasets from [fivethirtyeight](https://github.com/fivethirtyeight/data) We can read the csv file directly over the internet from the github location.

# %%
# Create a DataFrame object using read_csv() function
alcohol_data = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv')
# Display the DataFrame
print(alcohol_data.head())
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %% [markdown]
# Another common scenario is to query relational database tables using SQL language. You can apply the read_sql() function to pass the SQL query and load the result into a Pandas DataFrame object.
#
# The following code will create a local database using the Python SQLite engine. We will then use Pandas to access the data using SQL queries.

# %%
# Import SQLite library
import sqlite3

# Assign the database name
db_path = 'address_book.db'

# Create the database file
conn = sqlite3.connect(db_path)

# Establish a connection with the database file
c = conn.cursor()

# Create a database table
c.execute("""CREATE TABLE if not exists my_table
         (first_name, last_name, phone_number)""")

# Add some data
c.execute("""INSERT INTO my_table (first_name, last_name, phone_number)
          values('James', 'Shoehorn', '123.235.5478')""")
c.execute("""INSERT INTO my_table (first_name, last_name, phone_number)
          values('Amanda', 'Kindes', '123.235.5478')""")
c.execute("""INSERT INTO my_table (first_name, last_name, phone_number)
          values('Amaramath', 'Slowfoot', '123.235.5478')""")
# Commit changes and close the connection
conn.commit()

# Close the connection
c.close()

# %% [markdown]
# The relational database name address_book.db should appear as an external file in the same location with your notebook. The database will be deleted each time you exit your Colab sessions.
#
# The following code queries the data into a Pandas DataFrame object.

# %%
# Identify the database name
database = 'address_book.db'

# Establish a connection with the database file
conn = sqlite3.connect(database)

# Use Pandas function to pass SQL query and create a DataFrame object
people = pd.read_sql("select * from my_table", con = conn)

# Print the generated DataFrame
print(people)

# Close the connection
conn.close()
# Out:
#   first_name last_name  phone_number
# 0      James  Shoehorn  123.235.5478
# 1     Amanda    Kindes  123.235.5478
# 2  Amaramath  Slowfoot  123.235.5478
# 3      James  Shoehorn  123.235.5478
# 4     Amanda    Kindes  123.235.5478
# 5  Amaramath  Slowfoot  123.235.5478

# %% [markdown]
# ## API Query and JSON

# %% [markdown]
# When working on daily tasks, data professionals often need to access data from third-party APIs. This approach is common when the data is continually updated like weather forecasting or when you need to select a small subset of data. API response data usually comes in JSON format which you can think of as a collection of Python data structures like dictionaries and lists represented as text.
#
# We will use API data from open-notify to get information about the International Space Station ISS. The following code will make a query about current crew members onboard ISS. We will use the Python request library to establish a connection with the API.

# %%
# Import requests library to handle API connection
import requests

# Import and initialize Data pretty printer library
import pprint
pp = pprint.PrettyPrinter(indent=4)

# Pass the API query using requests library
response = requests.get("http://api.open-notify.org/astros.json")

# Convert response data into JSON format
response_data = response.json()

# Examine the response data
pp.pprint(response_data)
# Out:
# {   'message': 'success',
#     'number': 11,
#     'people': [   {'craft': 'ISS', 'name': 'Raja Chari'},
#                   {'craft': 'ISS', 'name': 'Tom Marshburn'},
#                   {'craft': 'ISS', 'name': 'Kayla Barron'},
#                   {'craft': 'ISS', 'name': 'Matthias Maurer'},
#                   {'craft': 'ISS', 'name': 'Oleg Artemyev'},
#                   {'craft': 'ISS', 'name': 'Denis Matveev'},
#                   {'craft': 'ISS', 'name': 'Sergey Korsakov'},
#                   {'craft': 'ISS', 'name': 'Michael Lopez-Alegria'},
#                   {'craft': 'ISS', 'name': 'Larry Connor'},
#                   {'craft': 'ISS', 'name': 'Mark Pathy'},
#                   {'craft': 'ISS', 'name': 'Eytan Stibbe'}]}

# %% [markdown]
# Notice that the response includes a list of dictionaries about the astronauts currently aboard the ISS. We can convert this part of the response into a Pandas DataFrame object as shown in the example below:

# %%
# Create a DataFrame of astronauts currently aboard the ISS
# Specify the people list of dictionaries
astronauts = pd.DataFrame(response_data['people'])
# Display the DataFrame
astronauts
# Out:
#                      name craft
# 0              Raja Chari   ISS
# 1           Tom Marshburn   ISS
# 2            Kayla Barron   ISS
# 3         Matthias Maurer   ISS
# 4           Oleg Artemyev   ISS
# 5           Denis Matveev   ISS
# 6         Sergey Korsakov   ISS
# 7   Michael Lopez-Alegria   ISS
# 8            Larry Connor   ISS
# 9              Mark Pathy   ISS
# 10           Eytan Stibbe   ISS

# %% [markdown]
# ## Statistics and Random Numbers

# %% [markdown]
# How to generate random numbers with numpy default_rng
# * default_rng() is the constructor that uses [PCG64](https://numpy.org/doc/stable/reference/random/bit_generators/pcg64.html)
# * https://numpy.org/doc/stable/reference/random/index.html#random-quick-start

# %% [markdown]
# Sample of float and integer numpy random number generation

# %%
# Random number generation with numpy Generator
from numpy.random import default_rng
rng = default_rng()
vals = rng.standard_normal(10)
print(vals)
more_vals = rng.standard_normal(10)
print(more_vals)
# Generate {size} random numbers on uniform interval
x = rng.integers(low=0, high=1000, size=20)

# Generate {size} random integers on uniform interval
x = rng.integers(low=0, high=1000, size=20)
print(x)
# Out:
# [ 0.04724435  0.73999054  1.70517035 -2.09324228  0.58836138 -1.4472055
#  -0.75703828 -0.36724859 -0.78300742  2.02753572]
# [-0.22737643 -0.56159278 -0.69711788 -1.44508794 -0.50128223  0.38708112
#   1.29042619 -0.89638454 -0.40895266  0.49718553]
# [762 822 115 888 970 254  83 666 252 966 693 378 732 229 515 606 809 632
#  961 879]

# %% [markdown]
# **A Lot of Random Numbers**
# * Create numpy array of floats between 0 and 100
# * Convert numpy array to a pandas dataframe
# * Display panda dataframe statistics

# %% [markdown]
# This uses normal Python math to generate a list of 1,000,000 floats between 0 and 100. Look at the execution time.

# %%
# Generate 1,000,000
import random
import math

rand_list=[]
n=1000_000
for i in range(n):
	rand_list.append(random.uniform(0,100) * 100)

def Average(lst):
    return sum(lst) / len(lst)
  
average = Average(rand_list)
  
# Printing average of the list
print("Average of the list =", round(average, 2))
print(f"Sum: {sum(rand_list)}")
print(f"Max: {max(rand_list)}")
print(f"Min: {min(rand_list)}")
# Out:
# Average of the list = 4999.32
# Sum: 4999324319.476648
# Max: 9999.993612009832
# Min: 0.03162284784363756

# %% [markdown]
# Using numpy and pandas is much faster.

# %%
from numpy.random import default_rng
import pandas as pd

size = 1000_000
# Create Generator default object
rng = default_rng()

# Use numpy to generate random floats between 0 and 100
random_numbers = rng.random(size=size) * 100

# Create a pandas dataframe of the random floats
df = pd.DataFrame({'number': random_numbers})

# Display results
print(f"Statistics on {size:,} random numbers")
print(f"First 5 numbers: {df['number'].head(5)}")
print(f"\nSum: {df['number'].sum()}")
print(f"Mean: {df['number'].mean()}")
print(f"Median: {df['number'].median()}")
print(f"\nThe pandas describe method")
print(f"Describe: {df['number'].describe()}")
# Out:
# Statistics on 1,000,000 random numbers
# First 5 numbers: 0    19.088102
# 1    34.782956
# 2    31.352412
# 3    50.367429
# 4    82.157955
# Name: number, dtype: float64
#
# Sum: 50013314.48169517
# Mean: 50.01331448169501
# Median: 49.99895772115173
#
# The pandas describe method
# Describe: count    1000000.000000
# mean          50.013314
# std           28.858324
# min            0.000287
# 25%           25.064512
# 50%           49.998958
# 75%           75.027059
# max           99.999829
# Name: number, dtype: float64

# %% [markdown]
# ## Going Further

# %% [markdown]
# *	Python Data Science Handbook [Chapter 3: Data Manipulation with Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)
# * Pandas tutorials [Github collection of notebooks](https://github.com/TirendazAcademy/PANDAS-TUTORIAL)

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Plot Creation

# %% [markdown]
# Matplotlib is a plotting library for Python.

# %%
# Find the matplotlib version in a notebook
import sys
import matplotlib
print(f"matplotlib: {matplotlib.__version__}")
# Out:
# matplotlib: 3.2.2

# %% [markdown]
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.
#
# **Example:** Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Here we use the bar() method to draw a bar graph from 2 NumPy arrays.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# A Pie chart.

# %%
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Here is a plotting example derived from a NumPy linspace array.

# %%
from matplotlib import pyplot as plt
# Values from -3 to 3 in 100 steps
x_values = np.linspace(-3, 3, 100)

plt.figure()
plt.plot(x_values, np.sin(x_values), label="Sinusoid")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Matplotlib example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# We continue with a rudimentary scatter plot example. This example displays samples from the [iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html) using the first two features. Colors indicate class membership (there are 3 classes).

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

X_class0 = X[y == 0]
X_class1 = X[y == 1]
X_class2 = X[y == 2]

plt.figure()
plt.scatter(X_class0[:, 0], X_class0[:, 1], label="Class 0", color="C0")
plt.scatter(X_class1[:, 0], X_class1[:, 1], label="Class 1", color="C1")
plt.scatter(X_class2[:, 0], X_class2[:, 1], label="Class 2", color="C2")
plt.show()

# %% [markdown]
# We see that samples belonging to class 0 can be linearly separated from the rest using only the first two features.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 2.** Repeat the same scatter plot but using the [digits dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) instead.

# %%
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)

# %% [markdown]
# ## Going Further

# %% [markdown]
# * Python Data Science Handbook [Chapter 5: Visualization with Matplotlib](https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html)

# %% [markdown]
# #  Pandas and Matplotlib

# %% [markdown]
# Pandas works very closely with Matplotlib

# %%
import pandas as pd

df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})
df
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %% [markdown]
# Bar plot of column values

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a simple line plot
df.plot(kind='bar',x='name',y='age')

# %% [markdown]
# Bar plot with group by and numique

# %%
import matplotlib.pyplot as plt
import pandas as pd

df.groupby('state')['name'].nunique().plot(kind='bar')
plt.show()

# %% [markdown]
# # Resources

# %% [markdown]
# * [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/) (Free under Creative Commons and MIT copyright)

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by/3.0/us/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by/3.0/us/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/3.0/us/">Creative Commons Attribution 3.0 United States License</a>.
